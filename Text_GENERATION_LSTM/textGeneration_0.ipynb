# %%
# I have downloaded a poetry wrtitten by W.H. Auden. In this notebook I will develop a RNN/LSTM model to learn the poetry.

# %%
# import necessary packages
import numpy
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from keras.layers import Dropout
from keras.callbacks import ModelCheckpoint
from keras.utils import np_utils

# %%
# We need to load the ASCII text for the poetry into memory and convert all of the characters 
# to lowercase to reduce the vocabulary that the network must learn.

# %%
# load ascii text and covert to lowercase
filename = "poetry_WH_Auden.txt"
raw_text = open(filename).read()
raw_text = raw_text.lower()

# %%
#  We must prepare the data for modeling by the neural network. We cannot model the characters directly, 
#  instead we must convert the characters to integers.

# %%
# create mapping of unique chars to integers
chars = sorted(list(set(raw_text)))
char_to_int = dict((c, i) for i, c in enumerate(chars))

# %%
# summarize the loaded data
n_chars = len(raw_text)
n_vocab = len(chars)
print("Total Characters: ", n_chars)
print("Total Vocab: ", n_vocab)
# Out:
# Total Characters:  2525
# Total Vocab:  33

# %%
# We split up the book into these sequences, we convert the characters 
# to integers using our lookup table we prepared earlier.

# %%
# prepare the dataset of input to output pairs encoded as integers
seq_length = 100
dataX = []
dataY = []
for i in range(0, n_chars - seq_length, 1):
    seq_in = raw_text[i:i + seq_length]
    seq_out = raw_text[i + seq_length]
    dataX.append([char_to_int[char] for char in seq_in])
    dataY.append(char_to_int[seq_out])
n_patterns = len(dataX)
print("Total Patterns: ", n_patterns)
# Out:
# Total Patterns:  2425

# %%
# We must transform the list of input sequences into the form 
# [samples, time steps, features] expected by an LSTM network.
# Next we need to rescale the integers to the range 0-to-1 to make the patterns easier to 
# learn by the LSTM network that uses the sigmoid activation function by default.

# %%
# reshape X to be [samples, time steps, features]
X = numpy.reshape(dataX, (n_patterns, seq_length, 1))
# normalize
X = X / float(n_vocab)
# one hot encode the output variable
y = np_utils.to_categorical(dataY)

# %%
# define the LSTM model
model = Sequential()
model.add(LSTM(256, input_shape=(X.shape[1], X.shape[2]), return_sequences=True))
model.add(Dropout(0.2))
model.add(LSTM(256))
model.add(Dropout(0.2))
model.add(Dense(y.shape[1], activation='softmax'))
model.compile(loss='categorical_crossentropy', optimizer='adam')

# %%
# define the checkpoint
filepath="weights-improvement-{epoch:02d}-{loss:.4f}.hdf5"
checkpoint = ModelCheckpoint(filepath, monitor='loss', verbose=1, save_best_only=True, mode='min')
callbacks_list = [checkpoint]

# %%
# fit the model
model.fit(X, y, epochs=100, batch_size=64, callbacks=callbacks_list)
# Out:
# Epoch 1/100
# 2425/2425 [==============================] - 33s 14ms/step - loss: 3.0997
#
# Epoch 00001: loss improved from inf to 3.09972, saving model to weights-improvement-01-3.0997.hdf5
# Epoch 2/100
# 2425/2425 [==============================] - 31s 13ms/step - loss: 3.0195
#
# Epoch 00002: loss improved from 3.09972 to 3.01955, saving model to weights-improvement-02-3.0195.hdf5
# Epoch 3/100
# 2425/2425 [==============================] - 33s 14ms/step - loss: 3.0212
#
# Epoch 00003: loss did not improve from 3.01955
# Epoch 4/100
# 2425/2425 [==============================] - 30s 12ms/step - loss: 3.0110
#
# Epoch 00004: loss improved from 3.01955 to 3.01100, saving model to weights-improvement-04-3.0110.hdf5
# Epoch 5/100
# 2425/2425 [==============================] - 32s 13ms/step - loss: 3.0015
#
# Epoch 00005: loss improved from 3.01100 to 3.00152, saving model to weights-improvement-05-3.0015.hdf5
# Epoch 6/100
# 2425/2425 [==============================] - 32s 13ms/step - loss: 2.9948
#
# Epoch 00006: loss improved from 3.00152 to 2.99484, saving model to weights-improvement-06-2.9948.hdf5
# Epoch 7/100
# 2425/2425 [==============================] - 34s 14ms/step - loss: 2.9967
#
# Epoch 00007: loss did not improve from 2.99484
# Epoch 8/100
# 2425/2425 [==============================] - 34s 14ms/step - loss: 2.9963
#
# Epoch 00008: loss did not improve from 2.99484
# Epoch 9/100
# 2425/2425 [==============================] - 31s 13ms/step - loss: 2.9902
#
# Epoch 00009: loss improved from 2.99484 to 2.99022, saving model to weights-improvement-09-2.9902.hdf5
# Epoch 10/100
# 2425/2425 [==============================] - 31s 13ms/step - loss: 2.9806
#
# Epoch 00010: loss improved from 2.99022 to 2.98063, saving model to weights-improvement-10-2.9806.hdf5
# Epoch 11/100
# 2425/2425 [==============================] - 31s 13ms/step - loss: 2.9625
#
# Epoch 00011: loss improved from 2.98063 to 2.96247, saving model to weights-improvement-11-2.9625.hdf5
# Epoch 12/100
# 2425/2425 [==============================] - 31s 13ms/step - loss: 2.9580
#
# Epoch 00012: loss improved from 2.96247 to 2.95797, saving model to weights-improvement-12-2.9580.hdf5
# Epoch 13/100
# 2425/2425 [==============================] - 31s 13ms/step - loss: 2.9450
#
# Epoch 00013: loss improved from 2.95797 to 2.94501, saving model to weights-improvement-13-2.9450.hdf5
# Epoch 14/100
# 2425/2425 [==============================] - 31s 13ms/step - loss: 2.9331
#
# Epoch 00014: loss improved from 2.94501 to 2.93315, saving model to weights-improvement-14-2.9331.hdf5
# Epoch 15/100
# 2425/2425 [==============================] - 32s 13ms/step - loss: 2.9080
#
# Epoch 00015: loss improved from 2.93315 to 2.90802, saving model to weights-improvement-15-2.9080.hdf5
# Epoch 16/100
# 2425/2425 [==============================] - 31s 13ms/step - loss: 2.8916
#
# Epoch 00016: loss improved from 2.90802 to 2.89161, saving model to weights-improvement-16-2.8916.hdf5
# Epoch 17/100
# 2425/2425 [==============================] - 32s 13ms/step - loss: 2.8614
#
# Epoch 00017: loss improved from 2.89161 to 2.86137, saving model to weights-improvement-17-2.8614.hdf5
# Epoch 18/100
# 2425/2425 [==============================] - 31s 13ms/step - loss: 2.8506
#
# Epoch 00018: loss improved from 2.86137 to 2.85065, saving model to weights-improvement-18-2.8506.hdf5
# Epoch 19/100
# 2425/2425 [==============================] - 31s 13ms/step - loss: 2.8154
#
# Epoch 00019: loss improved from 2.85065 to 2.81543, saving model to weights-improvement-19-2.8154.hdf5
# Epoch 20/100
# 2425/2425 [==============================] - 31s 13ms/step - loss: 2.7892
#
# Epoch 00020: loss improved from 2.81543 to 2.78924, saving model to weights-improvement-20-2.7892.hdf5
# Epoch 21/100
# 2425/2425 [==============================] - 32s 13ms/step - loss: 2.7633
#
# Epoch 00021: loss improved from 2.78924 to 2.76329, saving model to weights-improvement-21-2.7633.hdf5
# Epoch 22/100
# 2425/2425 [==============================] - 31s 13ms/step - loss: 2.7228
#
# Epoch 00022: loss improved from 2.76329 to 2.72282, saving model to weights-improvement-22-2.7228.hdf5
# Epoch 23/100
# 2425/2425 [==============================] - 30s 12ms/step - loss: 2.6948
#
# Epoch 00023: loss improved from 2.72282 to 2.69481, saving model to weights-improvement-23-2.6948.hdf5
# Epoch 24/100
# 2425/2425 [==============================] - 30s 12ms/step - loss: 2.6648
#
# Epoch 00024: loss improved from 2.69481 to 2.66475, saving model to weights-improvement-24-2.6648.hdf5
# Epoch 25/100
# 2425/2425 [==============================] - 30s 12ms/step - loss: 2.6196
#
# Epoch 00025: loss improved from 2.66475 to 2.61963, saving model to weights-improvement-25-2.6196.hdf5
# Epoch 26/100
# 2425/2425 [==============================] - 30s 12ms/step - loss: 2.5911
#
# Epoch 00026: loss improved from 2.61963 to 2.59106, saving model to weights-improvement-26-2.5911.hdf5
# Epoch 27/100
# 2425/2425 [==============================] - 31s 13ms/step - loss: 2.5373
#
# Epoch 00027: loss improved from 2.59106 to 2.53728, saving model to weights-improvement-27-2.5373.hdf5
# Epoch 28/100
# 2425/2425 [==============================] - 30s 12ms/step - loss: 2.4954
#
# Epoch 00028: loss improved from 2.53728 to 2.49542, saving model to weights-improvement-28-2.4954.hdf5
# Epoch 29/100
# 2425/2425 [==============================] - 30s 12ms/step - loss: 2.4585
#
# Epoch 00029: loss improved from 2.49542 to 2.45850, saving model to weights-improvement-29-2.4585.hdf5
# Epoch 30/100
# 2425/2425 [==============================] - 30s 12ms/step - loss: 2.3739
#
# Epoch 00030: loss improved from 2.45850 to 2.37390, saving model to weights-improvement-30-2.3739.hdf5
# Epoch 31/100
# 2425/2425 [==============================] - 30s 12ms/step - loss: 2.3136
#
# Epoch 00031: loss improved from 2.37390 to 2.31357, saving model to weights-improvement-31-2.3136.hdf5
# Epoch 32/100
# 2425/2425 [==============================] - 30s 12ms/step - loss: 2.2685
#
# Epoch 00032: loss improved from 2.31357 to 2.26847, saving model to weights-improvement-32-2.2685.hdf5
# Epoch 33/100
# 2425/2425 [==============================] - 30s 12ms/step - loss: 2.1810
#
# Epoch 00033: loss improved from 2.26847 to 2.18103, saving model to weights-improvement-33-2.1810.hdf5
# Epoch 34/100
# 2425/2425 [==============================] - 30s 12ms/step - loss: 2.1072
#
# Epoch 00034: loss improved from 2.18103 to 2.10718, saving model to weights-improvement-34-2.1072.hdf5
# Epoch 35/100
# 2425/2425 [==============================] - 30s 12ms/step - loss: 1.9786
#
# Epoch 00035: loss improved from 2.10718 to 1.97859, saving model to weights-improvement-35-1.9786.hdf5
# Epoch 36/100
# 2425/2425 [==============================] - 30s 12ms/step - loss: 1.8976
#
# Epoch 00036: loss improved from 1.97859 to 1.89762, saving model to weights-improvement-36-1.8976.hdf5
# Epoch 37/100
# 2425/2425 [==============================] - 30s 12ms/step - loss: 1.7568
#
# Epoch 00037: loss improved from 1.89762 to 1.75675, saving model to weights-improvement-37-1.7568.hdf5
# Epoch 38/100
# 2425/2425 [==============================] - 30s 12ms/step - loss: 1.6775
#
# Epoch 00038: loss improved from 1.75675 to 1.67753, saving model to weights-improvement-38-1.6775.hdf5
# Epoch 39/100
# 2425/2425 [==============================] - 30s 12ms/step - loss: 1.5700
#
# Epoch 00039: loss improved from 1.67753 to 1.56996, saving model to weights-improvement-39-1.5700.hdf5
# Epoch 40/100
# 2425/2425 [==============================] - 30s 12ms/step - loss: 1.4479
#
# Epoch 00040: loss improved from 1.56996 to 1.44786, saving model to weights-improvement-40-1.4479.hdf5
# Epoch 41/100
# 2425/2425 [==============================] - 30s 12ms/step - loss: 1.3376
#
# Epoch 00041: loss improved from 1.44786 to 1.33755, saving model to weights-improvement-41-1.3376.hdf5
# Epoch 42/100
# 2425/2425 [==============================] - 30s 12ms/step - loss: 1.1845
#
# Epoch 00042: loss improved from 1.33755 to 1.18449, saving model to weights-improvement-42-1.1845.hdf5
# Epoch 43/100
# 2425/2425 [==============================] - 30s 12ms/step - loss: 1.0920
#
# Epoch 00043: loss improved from 1.18449 to 1.09204, saving model to weights-improvement-43-1.0920.hdf5
# Epoch 44/100
# 2425/2425 [==============================] - 30s 12ms/step - loss: 0.9858
#
# Epoch 00044: loss improved from 1.09204 to 0.98579, saving model to weights-improvement-44-0.9858.hdf5
# Epoch 45/100
# 2425/2425 [==============================] - 30s 12ms/step - loss: 0.8807
#
# Epoch 00045: loss improved from 0.98579 to 0.88072, saving model to weights-improvement-45-0.8807.hdf5
# Epoch 46/100
# 2425/2425 [==============================] - 30s 12ms/step - loss: 0.8067
#
# Epoch 00046: loss improved from 0.88072 to 0.80669, saving model to weights-improvement-46-0.8067.hdf5
# Epoch 47/100
# 2425/2425 [==============================] - 30s 12ms/step - loss: 0.6990
#
# Epoch 00047: loss improved from 0.80669 to 0.69900, saving model to weights-improvement-47-0.6990.hdf5
# Epoch 48/100
# 2425/2425 [==============================] - 30s 12ms/step - loss: 0.6240
#
# Epoch 00048: loss improved from 0.69900 to 0.62403, saving model to weights-improvement-48-0.6240.hdf5
# Epoch 49/100
# 2425/2425 [==============================] - 30s 12ms/step - loss: 0.5418
#
# Epoch 00049: loss improved from 0.62403 to 0.54182, saving model to weights-improvement-49-0.5418.hdf5
# Epoch 50/100
# 2425/2425 [==============================] - 30s 12ms/step - loss: 0.4758
#
# Epoch 00050: loss improved from 0.54182 to 0.47578, saving model to weights-improvement-50-0.4758.hdf5
# Epoch 51/100
# 2425/2425 [==============================] - 30s 12ms/step - loss: 0.4150
#
# Epoch 00051: loss improved from 0.47578 to 0.41504, saving model to weights-improvement-51-0.4150.hdf5
# Epoch 52/100
# 2425/2425 [==============================] - 30s 12ms/step - loss: 0.3690
#
# Epoch 00052: loss improved from 0.41504 to 0.36903, saving model to weights-improvement-52-0.3690.hdf5
# Epoch 53/100
# 2425/2425 [==============================] - 30s 12ms/step - loss: 0.3209
#
# Epoch 00053: loss improved from 0.36903 to 0.32090, saving model to weights-improvement-53-0.3209.hdf5
# Epoch 54/100
# 2425/2425 [==============================] - 30s 12ms/step - loss: 0.2856
#
# Epoch 00054: loss improved from 0.32090 to 0.28563, saving model to weights-improvement-54-0.2856.hdf5
# Epoch 55/100
# 2425/2425 [==============================] - 30s 12ms/step - loss: 0.2607
#
# Epoch 00055: loss improved from 0.28563 to 0.26070, saving model to weights-improvement-55-0.2607.hdf5
# Epoch 56/100
# 2425/2425 [==============================] - 30s 12ms/step - loss: 0.2272
#
# Epoch 00056: loss improved from 0.26070 to 0.22721, saving model to weights-improvement-56-0.2272.hdf5
# Epoch 57/100
# 2425/2425 [==============================] - 30s 12ms/step - loss: 0.1956
#
# Epoch 00057: loss improved from 0.22721 to 0.19556, saving model to weights-improvement-57-0.1956.hdf5
# Epoch 58/100
# 2425/2425 [==============================] - 30s 12ms/step - loss: 0.1764
#
# Epoch 00058: loss improved from 0.19556 to 0.17644, saving model to weights-improvement-58-0.1764.hdf5
# Epoch 59/100
# 2425/2425 [==============================] - 30s 12ms/step - loss: 0.1641
#
# Epoch 00059: loss improved from 0.17644 to 0.16411, saving model to weights-improvement-59-0.1641.hdf5
# Epoch 60/100
# 2425/2425 [==============================] - 30s 12ms/step - loss: 0.1466
#
# Epoch 00060: loss improved from 0.16411 to 0.14662, saving model to weights-improvement-60-0.1466.hdf5
# Epoch 61/100
# 2425/2425 [==============================] - 30s 12ms/step - loss: 0.1420
#
# Epoch 00061: loss improved from 0.14662 to 0.14200, saving model to weights-improvement-61-0.1420.hdf5
# Epoch 62/100
# 2425/2425 [==============================] - 30s 12ms/step - loss: 0.1196
#
# Epoch 00062: loss improved from 0.14200 to 0.11959, saving model to weights-improvement-62-0.1196.hdf5
# Epoch 63/100
# 2425/2425 [==============================] - 30s 12ms/step - loss: 0.1141
#
# Epoch 00063: loss improved from 0.11959 to 0.11410, saving model to weights-improvement-63-0.1141.hdf5
# Epoch 64/100
# 2425/2425 [==============================] - 30s 12ms/step - loss: 0.1022
#
# Epoch 00064: loss improved from 0.11410 to 0.10219, saving model to weights-improvement-64-0.1022.hdf5
# Epoch 65/100
# 2425/2425 [==============================] - 30s 12ms/step - loss: 0.0943
#
# Epoch 00065: loss improved from 0.10219 to 0.09428, saving model to weights-improvement-65-0.0943.hdf5
# Epoch 66/100
# 2425/2425 [==============================] - 30s 12ms/step - loss: 0.0907
#
# Epoch 00066: loss improved from 0.09428 to 0.09065, saving model to weights-improvement-66-0.0907.hdf5
# Epoch 67/100
# 2425/2425 [==============================] - 30s 12ms/step - loss: 0.0835
#
# Epoch 00067: loss improved from 0.09065 to 0.08353, saving model to weights-improvement-67-0.0835.hdf5
# Epoch 68/100
# 2425/2425 [==============================] - 30s 12ms/step - loss: 0.0762
#
# Epoch 00068: loss improved from 0.08353 to 0.07620, saving model to weights-improvement-68-0.0762.hdf5
# Epoch 69/100
# 2425/2425 [==============================] - 30s 12ms/step - loss: 0.0748
#
# Epoch 00069: loss improved from 0.07620 to 0.07476, saving model to weights-improvement-69-0.0748.hdf5
# Epoch 70/100
# 2425/2425 [==============================] - 30s 12ms/step - loss: 0.0691
#
# Epoch 00070: loss improved from 0.07476 to 0.06912, saving model to weights-improvement-70-0.0691.hdf5
# Epoch 71/100
# 2425/2425 [==============================] - 30s 12ms/step - loss: 0.0609
#
# Epoch 00071: loss improved from 0.06912 to 0.06092, saving model to weights-improvement-71-0.0609.hdf5
# Epoch 72/100
# 2425/2425 [==============================] - 30s 12ms/step - loss: 0.0567
#
# Epoch 00072: loss improved from 0.06092 to 0.05666, saving model to weights-improvement-72-0.0567.hdf5
# Epoch 73/100
# 2425/2425 [==============================] - 30s 12ms/step - loss: 0.0501
#
# Epoch 00073: loss improved from 0.05666 to 0.05015, saving model to weights-improvement-73-0.0501.hdf5
# Epoch 74/100
# 2425/2425 [==============================] - 30s 12ms/step - loss: 0.0525
#
# Epoch 00074: loss did not improve from 0.05015
# Epoch 75/100
# 2425/2425 [==============================] - 30s 12ms/step - loss: 0.0496
#
# Epoch 00075: loss improved from 0.05015 to 0.04961, saving model to weights-improvement-75-0.0496.hdf5
# Epoch 76/100
# 2425/2425 [==============================] - 30s 12ms/step - loss: 0.0473
#
# Epoch 00076: loss improved from 0.04961 to 0.04733, saving model to weights-improvement-76-0.0473.hdf5
# Epoch 77/100
# 2425/2425 [==============================] - 30s 12ms/step - loss: 0.0438
#
# Epoch 00077: loss improved from 0.04733 to 0.04385, saving model to weights-improvement-77-0.0438.hdf5
# Epoch 78/100
# 2425/2425 [==============================] - 30s 12ms/step - loss: 0.0427
#
# Epoch 00078: loss improved from 0.04385 to 0.04265, saving model to weights-improvement-78-0.0427.hdf5
# Epoch 79/100
# 2425/2425 [==============================] - 30s 12ms/step - loss: 0.0439
#
# Epoch 00079: loss did not improve from 0.04265
# Epoch 80/100
# 2425/2425 [==============================] - 30s 12ms/step - loss: 0.0370
#
# Epoch 00080: loss improved from 0.04265 to 0.03700, saving model to weights-improvement-80-0.0370.hdf5
# Epoch 81/100
# 2425/2425 [==============================] - 30s 12ms/step - loss: 0.0360
#
# Epoch 00081: loss improved from 0.03700 to 0.03595, saving model to weights-improvement-81-0.0360.hdf5
# Epoch 82/100
# 2425/2425 [==============================] - 30s 12ms/step - loss: 0.0344
#
# Epoch 00082: loss improved from 0.03595 to 0.03437, saving model to weights-improvement-82-0.0344.hdf5
# Epoch 83/100
# 2425/2425 [==============================] - 30s 12ms/step - loss: 0.0331
#
# Epoch 00083: loss improved from 0.03437 to 0.03312, saving model to weights-improvement-83-0.0331.hdf5
# Epoch 84/100
# 2425/2425 [==============================] - 30s 12ms/step - loss: 0.0330
#
# Epoch 00084: loss improved from 0.03312 to 0.03302, saving model to weights-improvement-84-0.0330.hdf5
# Epoch 85/100
# 2425/2425 [==============================] - 30s 12ms/step - loss: 0.0324
#
# Epoch 00085: loss improved from 0.03302 to 0.03244, saving model to weights-improvement-85-0.0324.hdf5
# Epoch 86/100
# 2425/2425 [==============================] - 30s 12ms/step - loss: 0.0342
#
# Epoch 00086: loss did not improve from 0.03244
# Epoch 87/100
# 2425/2425 [==============================] - 30s 12ms/step - loss: 0.0291
#
# Epoch 00087: loss improved from 0.03244 to 0.02909, saving model to weights-improvement-87-0.0291.hdf5
# Epoch 88/100
# 2425/2425 [==============================] - 30s 12ms/step - loss: 0.0356
#
# Epoch 00088: loss did not improve from 0.02909
# Epoch 89/100
# 2425/2425 [==============================] - 30s 12ms/step - loss: 0.0304
#
# Epoch 00089: loss did not improve from 0.02909
# Epoch 90/100
# 2425/2425 [==============================] - 30s 12ms/step - loss: 0.0266
#
# Epoch 00090: loss improved from 0.02909 to 0.02663, saving model to weights-improvement-90-0.0266.hdf5
# Epoch 91/100
# 2425/2425 [==============================] - 30s 12ms/step - loss: 0.0249
#
# Epoch 00091: loss improved from 0.02663 to 0.02495, saving model to weights-improvement-91-0.0249.hdf5
# Epoch 92/100
# 2425/2425 [==============================] - 30s 12ms/step - loss: 0.0235
#
# Epoch 00092: loss improved from 0.02495 to 0.02351, saving model to weights-improvement-92-0.0235.hdf5
# Epoch 93/100
# 2425/2425 [==============================] - 30s 12ms/step - loss: 0.0242
#
# Epoch 00093: loss did not improve from 0.02351
# Epoch 94/100
# 2425/2425 [==============================] - 30s 12ms/step - loss: 0.0228
#
# Epoch 00094: loss improved from 0.02351 to 0.02278, saving model to weights-improvement-94-0.0228.hdf5
# Epoch 95/100
# 2425/2425 [==============================] - 30s 12ms/step - loss: 0.0214
#
# Epoch 00095: loss improved from 0.02278 to 0.02138, saving model to weights-improvement-95-0.0214.hdf5
# Epoch 96/100
# 2425/2425 [==============================] - 30s 12ms/step - loss: 0.0192
#
# Epoch 00096: loss improved from 0.02138 to 0.01921, saving model to weights-improvement-96-0.0192.hdf5
# Epoch 97/100
# 2425/2425 [==============================] - 30s 12ms/step - loss: 0.0235
#
# Epoch 00097: loss did not improve from 0.01921
# Epoch 98/100
# 2425/2425 [==============================] - 30s 12ms/step - loss: 0.0212
#
# Epoch 00098: loss did not improve from 0.01921
# Epoch 99/100
# 2425/2425 [==============================] - 30s 12ms/step - loss: 0.0199
#
# Epoch 00099: loss did not improve from 0.01921
# Epoch 100/100
# 2425/2425 [==============================] - 30s 12ms/step - loss: 0.0196
#
# Epoch 00100: loss did not improve from 0.01921
