# %%
df.columns
df.indexes
df.dtypes
df.shape
df.describe()
df.shape[0]
df.head(5)
df.tail(5)
df.unique()
df.nunique()
pd.DataFrame({'Company':['TCS','HCL']})
df.index=['First','second','Third']
df.reset_index(inplace=True)
df.loc[['Second','Fourth']] # string indices
df.iloc[[3,4]] # integer indices
furniture.cost=furniture['Cost'].astype(float)
furniture.value_counts()
df.set_index('Company') # set one column as index
df.sort_values('Cost',ascending=False)
df.columns=['Col1','Col2','Col3'] # to rename the column names
df
# or
df.rename(columns={'Product':'Category'}, inplace=True)
df.drop('Col1', axis=1)
df.dropna()
df.fillna(method='ffill') #bfill
df.isnull()
df.isnull().sum()

# %%
import pandas as pd
df=pd.read_csv('projects_data.csv')
# Out:
# /home/ankur/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2728: DtypeWarning: Columns (44) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df.head()
# Out:
#         id  regionname                                        countryname  \
# 0  P162228       Other                                        World;World
# 1  P163962      Africa  Democratic Republic of the Congo;Democratic Re...
# 2  P167672  South Asia  People's Republic of Bangladesh;People's Repub...
# 3  P158768  South Asia  Islamic  Republic of Afghanistan;Islamic  Repu...
# 4  P161364      Africa  Federal Republic of Nigeria;Federal Republic o...
#
#   prodline                  lendinginstr lendinginstrtype  \
# 0       RE  Investment Project Financing               IN
# 1       PE  Investment Project Financing               IN
# 2       PE  Investment Project Financing               IN
# 3       PE  Investment Project Financing               IN
# 4       PE  Investment Project Financing               IN
#
#   envassesmentcategorycode supplementprojectflg productlinetype  \
# 0                        C                    N               L
# ...

# %%
df['regionname'].unique()
# Out:
# array(['Other', 'Africa', 'South Asia', 'Middle East and North Africa',
#        'Europe and Central Asia', 'East Asia and Pacific',
#        'Latin America and Caribbean'], dtype=object)

# %%
df['regionname'].nunique()
# Out:
# 7

# %%
import pandas as pd
li=[{'name':'John','age':32,'org':'TCS'},{'name':'Mike','age':33,'org':'HCL'}]

# %%
df_test=pd.DataFrame.from_dict(li)

# %%
df_test
# Out:
#    age  name  org
# 0   32  John  TCS
# 1   33  Mike  HCL

# %%
df_test['Sal']=pd.Series([2000,3000])

# %%
df_test
# Out:
#    age  name  org   Sal
# 0   32  John  TCS  2000
# 1   33  Mike  HCL  3000

# %%
df_test['sum']=df_test['age']+df_test['Sal']
df_test
# Out:
#    age  name  org   Sal   sum
# 0   32  John  TCS  2000  2032
# 1   33  Mike  HCL  3000  3033

# %%
df_test.index
# Out:
# RangeIndex(start=0, stop=2, step=1)

# %%
df_test.index=['First','Second']

# %%
df_test
# Out:
#         age  name  org
# First    32  John  TCS
# Second   33  Mike  HCL

# %% [markdown]
# ## encodings

# %%
import pandas as pd
df_mystery=pd.read_csv('mystery.csv')
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# <ipython-input-17-44430175f0bb> in <module>()
#       1 import pandas as pd
# ----> 2 df_mystery=pd.read_csv('mystery.csv')
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/io/parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, escapechar, comment, encoding, dialect, tupleize_cols, error_bad_lines, warn_bad_lines, skipfooter, doublequote, delim_whitespace, low_memory, memory_map, float_precision)
# ...

# %%
from encodings.aliases import aliases

alias_values = set(aliases.values())


for encoding in alias_values:
    try:
        df=pd.read_csv('mystery.csv', encoding=encoding)
        print('successful', encoding)
    except:
        pass
# Out:
# {'utf_32_le', 'koi8_r', 'iso2022_jp_3', 'euc_jp', 'cp1255', 'cp775', 'tactis', 'cp1125', 'cp1254', 'cp855', 'mac_latin2', 'shift_jis', 'bz2_codec', 'quopri_codec', 'cp1253', 'latin_1', 'johab', 'cp500', 'gbk', 'gb2312', 'mac_greek', 'cp037', 'cp862', 'hz', 'iso2022_jp_2004', 'cp273', 'iso8859_8', 'iso8859_11', 'cp861', 'cp437', 'mbcs', 'cp858', 'cp1251', 'kz1048', 'uu_codec', 'cp1258', 'rot_13', 'iso8859_15', 'ascii', 'cp1257', 'cp866', 'euc_kr', 'tis_620', 'iso8859_7', 'euc_jisx0213', 'cp850', 'utf_32', 'iso8859_14', 'mac_cyrillic', 'hp_roman8', 'cp424', 'iso2022_jp', 'mac_roman', 'utf_7', 'iso2022_kr', 'iso8859_2', 'utf_32_be', 'mac_iceland', 'utf_8', 'cp869', 'iso8859_4', 'iso8859_5', 'gb18030', 'cp932', 'iso8859_6', 'zlib_codec', 'cp1256', 'cp857', 'cp852', 'iso8859_9', 'euc_jis_2004', 'cp865', 'utf_16_le', 'base64_codec', 'iso2022_jp_ext', 'hex_codec', 'cp1250', 'utf_16_be', 'big5', 'cp1140', 'cp949', 'iso2022_jp_2', 'iso8859_10', 'shift_jisx0213', 'shift_jis_2004', 'utf_16', 'i
# ...

# %% [markdown]
# ## datatypes

# %%
import pandas as pd

# read in the population data and drop the final column
df_indicator = pd.read_csv('population_data.csv', skiprows=4)
pd.set_option('display.max_columns',1000)

# %%
df_indicator.head(2)
# Out:
#   Country Name Country Code     Indicator Name Indicator Code      1960  \
# 0        Aruba          ABW  Population, total    SP.POP.TOTL    54,211
# 1  Afghanistan          AFG  Population, total    SP.POP.TOTL 8,996,351
#
#        1961      1962      1963      1964      1965       1966       1967  \
# 0    55,438    56,225    56,695    57,032    57,360     57,715     58,055
# 1 9,166,764 9,345,868 9,533,954 9,731,361 9,938,414 10,152,331 10,372,630
#
#         1968       1969       1970       1971       1972       1973  \
# 0     58,386     58,726     59,063     59,440     59,840     60,243
# 1 10,604,346 10,854,428 11,126,123 11,417,825 11,721,940 12,027,822
#
#         1974       1975       1976       1977       1978       1979  \
# 0     60,528     60,657     60,586     60,366     60,103     59,980
# 1 12,321,541 12,590,286 12,840,299 13,067,538 13,237,734 13,306,695
#
#         1980       1981       1982       1983       1984       1985  \
# ...

# %%
df_indicator.drop(['Unnamed: 62'], axis=1, inplace=True)

# %%
df_indicator.dtypes
# Out:
# Country Name       object
# Country Code       object
# Indicator Name     object
# Indicator Code     object
# 1960              float64
# 1961              float64
# 1962              float64
# 1963              float64
# 1964              float64
# 1965              float64
# 1966              float64
# 1967              float64
# 1968              float64
# 1969              float64
# 1970              float64
# 1971              float64
# 1972              float64
# 1973              float64
# 1974              float64
# 1975              float64
# 1976              float64
# 1977              float64
# 1978              float64
# 1979              float64
# 1980              float64
# 1981              float64
# 1982              float64
# 1983              float64
# 1984              float64
# 1985              float64
#                    ...
# 1988              float64
# 1989              float64
# 1990              float64
# 1991              float64
# ...

# %%
# to change the float output into int
pd.options.display.float_format = '{:,.0f}'.format

# %%
df_nafta=df_indicator[(df_indicator['Country Name']=='Mexico') | (df_indicator['Country Name']=='Canada') |
                     (df_indicator['Country Name']=='United States')]

# %%
df_nafta
# Out:
#       Country Name Country Code     Indicator Name Indicator Code        1960  \
# 33          Canada          CAN  Population, total    SP.POP.TOTL  17,909,009
# 152         Mexico          MEX  Population, total    SP.POP.TOTL  38,174,112
# 249  United States          USA  Population, total    SP.POP.TOTL 180,671,000
#
#            1961        1962        1963        1964        1965        1966  \
# 33   18,271,000  18,614,000  18,964,000  19,325,000  19,678,000  20,048,000
# 152  39,394,126  40,649,588  41,939,880  43,264,272  44,623,043  46,011,038
# 249 183,691,000 186,538,000 189,242,000 191,889,000 194,303,000 196,560,000
#
#            1967        1968        1969        1970        1971        1972  \
# 33   20,412,000  20,744,000  21,028,000  21,324,000  21,645,535  21,993,631
# 152  47,429,812  48,894,019  50,423,481  52,029,861  53,718,724  55,478,151
# 249 198,712,000 200,706,000 202,677,000 205,052,000 207,661,000 209,896,000
#
# ...

# %%
keepcol = ['Country Name']
for i in range(1960, 2018, 1):
    keepcol.append(str(i))
keepcol    
df_nafta.sum(axis=0)[keepcol]
# Out:
# Country Name    CanadaMexicoUnited States
# 1960                          236,754,121
# 1961                          241,356,126
# 1962                          245,801,588
# 1963                          250,145,880
# 1964                          254,478,272
# 1965                          258,604,043
# 1966                          262,619,038
# 1967                          266,553,812
# 1968                          270,344,019
# 1969                          274,128,481
# 1970                          278,405,861
# 1971                          283,025,259
# 1972                          287,367,782
# 1973                          291,558,995
# 1974                          295,716,280
# 1975                          300,054,399
# 1976                          304,176,763
# 1977                          308,380,884
# 1978                          312,660,488
# 1979                          317,041,689
# 1980                          321,178,871
# ...

# %%
import pandas as pd
df_projects=pd.read_csv('projects_data.csv')
# Out:
# /home/ankur/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2728: DtypeWarning: Columns (44) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df_projects.head(2)
# Out:
#         id regionname                                        countryname  \
# 0  P162228      Other                                        World;World
# 1  P163962     Africa  Democratic Republic of the Congo;Democratic Re...
#
#   prodline                  lendinginstr lendinginstrtype  \
# 0       RE  Investment Project Financing               IN
# 1       PE  Investment Project Financing               IN
#
#   envassesmentcategorycode supplementprojectflg productlinetype  \
# 0                        C                    N               L
# 1                        B                    N               L
#
#   projectstatusdisplay  status  \
# 0               Active  Active
# 1               Active  Active
#
#                                         project_name     boardapprovaldate  \
# 0   Creating a Trade in Value-Added Database for ...  2018-06-28T00:00:00Z
# 1                       Productive Inclusion Project  2018-06-28T00:00:00Z
#
# ...

# %%
df_projects.drop(['Unnamed: 56'], axis=1, inplace=True)

# %%
df_projects.dtypes
# Out:
# id                           object
# regionname                   object
# countryname                  object
# prodline                     object
# lendinginstr                 object
# lendinginstrtype             object
# envassesmentcategorycode     object
# supplementprojectflg         object
# productlinetype              object
# projectstatusdisplay         object
# status                       object
# project_name                 object
# boardapprovaldate            object
# board_approval_month         object
# closingdate                  object
# lendprojectcost              object
# ibrdcommamt                  object
# idacommamt                   object
# totalamt                     object
# grantamt                     object
# borrower                     object
# impagency                    object
# url                          object
# projectdoc                  float64
# majorsector_percent         float64
# sector1                      object
# ...

# %%
df_projects[['totalamt','lendprojectcost']].head(5)
# Out:
#       totalamt lendprojectcost
# 0            0         500,000
# 1  200,000,000     200,000,000
# 2   58,330,000      50,000,000
# 3   20,000,000      50,000,000
# 4  100,000,000     100,000,000

# %%
df_projects['totalamt']=pd.to_numeric(df_projects['totalamt'].str.replace(',',''))

# %%
df_projects['lendprojectcost']=pd.to_numeric(df_projects['lendprojectcost'].str.replace(',',''))

# %%
df_projects[['totalamt','lendprojectcost']].dtypes
# Out:
# totalamt             int64
# lendprojectcost    float64
# dtype: object

# %% [markdown]
# ## imputing data

# %%
import pandas as pd
df_impute = pd.read_csv('gdp_data.csv', skiprows=4)
df_impute.drop('Unnamed: 62', axis=1, inplace=True)

# %%
df_impute.head()
# Out:
#   Country Name Country Code     Indicator Name  Indicator Code          1960  \
# 0        Aruba          ABW  GDP (current US$)  NY.GDP.MKTP.CD           NaN
# 1  Afghanistan          AFG  GDP (current US$)  NY.GDP.MKTP.CD  5.377778e+08
# 2       Angola          AGO  GDP (current US$)  NY.GDP.MKTP.CD           NaN
# 3      Albania          ALB  GDP (current US$)  NY.GDP.MKTP.CD           NaN
# 4      Andorra          AND  GDP (current US$)  NY.GDP.MKTP.CD           NaN
#
#            1961          1962          1963          1964          1965  \
# 0           NaN           NaN           NaN           NaN           NaN
# 1  5.488889e+08  5.466667e+08  7.511112e+08  8.000000e+08  1.006667e+09
# 2           NaN           NaN           NaN           NaN           NaN
# 3           NaN           NaN           NaN           NaN           NaN
# 4           NaN           NaN           NaN           NaN           NaN
#
# ...

# %%
df_impute.shape
# Out:
# (264, 62)

# %%
df_impute.isnull().sum()
# Out:
# Country Name        0
# Country Code        0
# Indicator Name      0
# Indicator Code      0
# 1960              140
# 1961              140
# 1962              139
# 1963              139
# 1964              139
# 1965              128
# 1966              127
# 1967              123
# 1968              119
# 1969              119
# 1970              111
# 1971              109
# 1972              109
# 1973              109
# 1974              108
# 1975              104
# 1976              103
# 1977               99
# 1978              100
# 1979               99
# 1980               87
# 1981               83
# 1982               77
# 1983               76
# 1984               74
# 1985               72
#                  ...
# 1988               64
# 1989               60
# 1990               44
# 1991               50
# 1992               47
# 1993               42
# 1994               37
# 1995               28
# 1996               27
# 1997               28
# ...

# %%
# put the data set into long form instead of wide
df_melt=pd.melt(df_impute, id_vars=['Country Name','Country Code','Indicator Name','Indicator Code'],
               var_name='year', value_name='GDP')

# %%
df_melt.head()
# Out:
#   Country Name Country Code     Indicator Name  Indicator Code  year  \
# 0        Aruba          ABW  GDP (current US$)  NY.GDP.MKTP.CD  1960
# 1  Afghanistan          AFG  GDP (current US$)  NY.GDP.MKTP.CD  1960
# 2       Angola          AGO  GDP (current US$)  NY.GDP.MKTP.CD  1960
# 3      Albania          ALB  GDP (current US$)  NY.GDP.MKTP.CD  1960
# 4      Andorra          AND  GDP (current US$)  NY.GDP.MKTP.CD  1960
#
#             GDP
# 0           NaN
# 1  5.377778e+08
# 2           NaN
# 3           NaN
# 4           NaN

# %%
df_melt.dtypes
# Out:
# Country Name       object
# Country Code       object
# Indicator Name     object
# Indicator Code     object
# year               object
# GDP               float64
# dtype: object

# %%
df_melt['year']=pd.to_datetime(df_melt['year'])

# %%
df_melt.dtypes
# Out:
# Country Name              object
# Country Code              object
# Indicator Name            object
# Indicator Code            object
# year              datetime64[ns]
# GDP                      float64
# dtype: object

# %%
df_melt.fillna(method='ffill')
# Out:
#                                             Country Name Country Code  \
# 0                                                  Aruba          ABW
# 1                                            Afghanistan          AFG
# 2                                                 Angola          AGO
# 3                                                Albania          ALB
# 4                                                Andorra          AND
# 5                                             Arab World          ARB
# 6                                   United Arab Emirates          ARE
# 7                                              Argentina          ARG
# 8                                                Armenia          ARM
# 9                                         American Samoa          ASM
# 10                                   Antigua and Barbuda          ATG
# 11                                             Australia          AUS
# ...

# %%
df_melt.head()
# Out:
#   Country Name Country Code     Indicator Name  Indicator Code       year  \
# 0        Aruba          ABW  GDP (current US$)  NY.GDP.MKTP.CD 1960-01-01
# 1  Afghanistan          AFG  GDP (current US$)  NY.GDP.MKTP.CD 1960-01-01
# 2       Angola          AGO  GDP (current US$)  NY.GDP.MKTP.CD 1960-01-01
# 3      Albania          ALB  GDP (current US$)  NY.GDP.MKTP.CD 1960-01-01
# 4      Andorra          AND  GDP (current US$)  NY.GDP.MKTP.CD 1960-01-01
#
#             GDP
# 0           NaN
# 1  5.377778e+08
# 2           NaN
# 3           NaN
# 4           NaN

# %% [markdown]
# ## Connection to Sqlite

# %%
import sqlite3
import pandas as pd

# connect to the database
conn=sqlite3.connect('population_data.db')

# run a query
pd.read_sql('select * from POPULATION_DATA', conn)
# Out:
#      index                                       Country_Name Country_Code  \
# 0        0                                              Aruba          ABW
# 1        1                                        Afghanistan          AFG
# 2        2                                             Angola          AGO
# 3        3                                            Albania          ALB
# 4        4                                            Andorra          AND
# 5        5                                         Arab World          ARB
# 6        6                               United Arab Emirates          ARE
# 7        7                                          Argentina          ARG
# 8        8                                            Armenia          ARM
# 9        9                                     American Samoa          ASM
# 10      10                                Antigua and Barbuda          ATG
# ...

# %% [markdown]
# ## Connection to Mysql or Postgresql

# %%
import pandas as pd
from sqlalchemy import create_engine

engine= create_engine('sqlite:///population_data.db')
pd.read_sql("SELECT * FROM population_data", engine)
# Out:
#      index                                       Country_Name Country_Code  \
# 0        0                                              Aruba          ABW
# 1        1                                        Afghanistan          AFG
# 2        2                                             Angola          AGO
# 3        3                                            Albania          ALB
# 4        4                                            Andorra          AND
# 5        5                                         Arab World          ARB
# 6        6                               United Arab Emirates          ARE
# 7        7                                          Argentina          ARG
# 8        8                                            Armenia          ARM
# 9        9                                     American Samoa          ASM
# 10      10                                Antigua and Barbuda          ATG
# ...
